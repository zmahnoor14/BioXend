# %%
import os
import sys
sys.path.append('/g/zimmermann/Members/zulfiqar/ZM000_PistoiaPrj/ChEMBL_Submission_Pipeline/ChEMBL_Submission_Pipeline')
from python.generate_compound_files import generate_compound_files

# %% [markdown]
# ## sdf as input
# should have a molecule name before the molecule entry starts <br>
# optional properties: COMPOUND_NAME, COMPOUND_KEY, COMPOUND_SOURCE

# %%
# output_dir = "/g/zimmermann/Members/zulfiqar/ZM000_PistoiaPrj/ChEMBL_Submission_Pipeline/ChEMBL_Submission_Pipeline/"
# input_file = "/g/zimmermann/Members/zulfiqar/ZM000_PistoiaPrj/ChEMBL_Submission_Pipeline/ChEMBL_Submission_Pipeline/inputs/compounds.sdf"
# RIDX = "GMM"
# prefix = "G"
# generate_compound_files(output_dir, input_file, RIDX, prefix)

# %% [markdown]
# ## csv as input
# should have a molecule name column termed as "ID" and a column with "SMILES". <br>
# optional columns: COMPOUND_NAME, COMPOUND_KEY, COMPOUND_SOURCE

# %%
output_dir = "/g/zimmermann/Members/zulfiqar/ZM000_PistoiaPrj/ChEMBL_Submission_Pipeline/ChEMBL_Submission_Pipeline/outputs"
input_file = "/g/zimmermann/Members/zulfiqar/ZM000_PistoiaPrj/ChEMBL_Submission_Pipeline/ChEMBL_Submission_Pipeline/inputs/compounds.csv"
RIDX = "HumanMicrobiome_DrugMetabolism"
prefix = "HMDM"

# %%
generate_compound_files(output_dir, input_file, RIDX, prefix)
# Out:
#                        ID                                             SMILES  \
# 0        ABACAVIR SULFATE               Nc1nc(NC2CC2)c2ncn(C3C=CC(CO)C3)c2n1
# 1              ACEBUTOLOL      CCCC(=O)Nc1ccc(OCC(O)C[NH2+]C(C)C)c(C(C)=O)c1
# 2              ACECAINIDE               CC[NH+](CC)CCNC(=O)c1ccc(NC(C)=O)cc1
# 3               ALFUZOSIN        COc1cc2nc(N(C)CCCNC(=O)C3CCCO3)nc(N)c2cc1OC
# 4             ALMOTRIPTAN     C[NH+](C)CCc1c[nH]c2ccc(CS(=O)(=O)N3CCCC3)cc12
# ..                    ...                                                ...
# 266              WARFARIN           CC(=O)CC(c1ccccc1)c1c([O-])c2ccccc2oc1=O
# 267              ZALEPLON           CCN(C(C)=O)c1cccc(-c2ccnc3c(C#N)cnn23)c1
# 268      ZIDOVUDINE [AZT]       Cc1cn(C2CC(N=[N+]=[N-])C(CO)O2)c(=O)[nH]c1=O
# 269  ZIPRASIDONE MESYLATE  O=C1Cc2cc(CC[NH+]3CCN(c4nsc5ccccc45)CC3)c(Cl)c...
# 270              ZOLPIDEM            Cc1ccc(-c2nc3ccc(C)cn3c2CC(=O)N(C)C)cc1
#
# ...
